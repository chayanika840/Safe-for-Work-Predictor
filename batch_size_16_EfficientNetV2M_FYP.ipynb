# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FYP/train'
validation_dataset_path = '/content/drive/MyDrive/FYP/val'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 16

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 80 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 23 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Nonnude
# 1 : Nude

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2M Model**
#
#
# ### i. Create a EfficientNetV2M Model

# %%
base_model = tf.keras.applications.EfficientNetV2M(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     include_preprocessing=True
                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Functiona  (None, 5, 5, 1280)       53150388
#  l)
#
#  batch_normalization (BatchN  (None, 5, 5, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 53,979,702
# Trainable params: 53,681,270
# Non-trainable params: 298,432
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 6.0 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
# early = tf.keras.callbacks.EarlyStopping( patience=10,
#                                           min_delta=0.001,
#                                           restore_best_weights=True)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=5,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=30,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# 5/5 - 82s - loss: 0.6035 - accuracy: 0.6750 - precision: 0.6750 - recall: 0.6750 - auc: 0.7450 - f1_Score: 0.5803 - val_loss: 0.4979 - val_accuracy: 0.7826 - val_precision: 0.7826 - val_recall: 0.7826 - val_auc: 0.8620 - val_f1_Score: 0.4390 - lr: 0.0010 - 82s/epoch - 16s/step
# Epoch 2/30
# 5/5 - 2s - loss: 0.5531 - accuracy: 0.8500 - precision: 0.8500 - recall: 0.8500 - auc: 0.8770 - f1_Score: 0.7656 - val_loss: 1.8764 - val_accuracy: 0.7826 - val_precision: 0.7826 - val_recall: 0.7826 - val_auc: 0.7826 - val_f1_Score: 0.4390 - lr: 0.0010 - 2s/epoch - 393ms/step
# Epoch 3/30
# 5/5 - 2s - loss: 0.3821 - accuracy: 0.7750 - precision: 0.7750 - recall: 0.7750 - auc: 0.9166 - f1_Score: 0.5867 - val_loss: 4.1959 - val_accuracy: 0.7826 - val_precision: 0.7826 - val_recall: 0.7826 - val_auc: 0.7826 - val_f1_Score: 0.4390 - lr: 0.0010 - 2s/epoch - 390ms/step
# Epoch 4/30
# 5/5 - 2s - loss: 0.1655 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9879 - f1_Score: 0.8880 - val_loss: 3.0725 - val_accuracy: 0.8261 - val_precision: 0.8261 - val_recall: 0.8261 - val_auc: 0.8185 - val_f1_Score: 0.6167 - lr: 0.0010 - 2s/epoch - 382ms/step
# Epoch 5/30
# 5/5 - 2s - loss: 0.2482 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9684 - f1_Score: 0.8925 - val_loss: 2.1540 - val_accuracy: 0.8261 - val_precision: 0.8261 - val_recall: 0.8261 - val_auc: 0.8261 - val_f1_Score: 0.6167 - lr: 0.0010 - 2s/epoch - 385ms/step
# Epoch 6/30
# 5/5 - 2s - loss: 0.7333 - accuracy: 0.8500 - precision: 0.8500 - recall: 0.8500 - auc: 0.9080 - f1_Score: 0.7929 - val_loss: 0.5353 - val_accuracy: 0.7391 - val_precision: 0.7391 - val_recall: 0.7391 - val_auc: 0.8299 - val_f1_Score: 0.5461 - lr: 0.0010 - 2s/epoch - 388ms/step
# Epoch 7/30
# 5/5 - 2s - loss: 0.3421 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9527 - f1_Score: 0.8828 - val_loss: 0.3907 - val_accuracy: 0.9130 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9149 - val_f1_Score: 0.8487 - lr: 3.1623e-04 - 2s/epoch - 379ms/step
# Epoch 8/30
# 5/5 - 2s - loss: 0.2526 - accuracy: 0.9000 - precision: 0.9000 - recall: 0.9000 - auc: 0.9578 - f1_Score: 0.8506 - val_loss: 0.6013 - val_accuracy: 0.6087 - val_precision: 0.6087 - val_recall: 0.6087 - val_auc: 0.7713 - val_f1_Score: 0.5801 - lr: 3.1623e-04 - 2s/epoch - 381ms/step
# Epoch 9/30
# 5/5 - 2s - loss: 0.2353 - accuracy: 0.8875 - precision: 0.8875 - recall: 0.8875 - auc: 0.9669 - f1_Score: 0.8524 - val_loss: 1.1897 - val_accuracy: 0.2174 - val_precision: 0.2174 - val_recall: 0.2174 - val_auc: 0.3554 - val_f1_Score: 0.1786 - lr: 3.1623e-04 - 2s/epoch - 383ms/step
# Epoch 10/30
# 5/5 - 2s - loss: 0.1014 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9969 - f1_Score: 0.9642 - val_loss: 1.8099 - val_accuracy: 0.2174 - val_precision: 0.2174 - val_recall: 0.2174 - val_auc: 0.3308 - val_f1_Score: 0.1786 - lr: 3.1623e-04 - 2s/epoch - 384ms/step
# Epoch 11/30
# 5/5 - 2s - loss: 0.0789 - accuracy: 0.9625 - precision: 0.9625 - recall: 0.9625 - auc: 0.9978 - f1_Score: 0.9427 - val_loss: 2.7556 - val_accuracy: 0.2174 - val_precision: 0.2174 - val_recall: 0.2174 - val_auc: 0.3119 - val_f1_Score: 0.1786 - lr: 3.1623e-04 - 2s/epoch - 388ms/step
# Epoch 12/30
# 5/5 - 2s - loss: 0.0631 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - auc: 0.9977 - f1_Score: 0.9824 - val_loss: 3.1482 - val_accuracy: 0.2174 - val_precision: 0.2174 - val_recall: 0.2174 - val_auc: 0.3119 - val_f1_Score: 0.1786 - lr: 3.1623e-04 - 2s/epoch - 385ms/step
# Epoch 13/30
# 5/5 - 2s - loss: 0.0140 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_Score: 1.0000 - val_loss: 1.0764 - val_accuracy: 0.6087 - val_precision: 0.6087 - val_recall: 0.6087 - val_auc: 0.6919 - val_f1_Score: 0.5965 - lr: 1.0000e-04 - 2s/epoch - 385ms/step
# Epoch 14/30
# 5/5 - 2s - loss: 0.0105 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_Score: 1.0000 - val_loss: 0.3111 - val_accuracy: 0.8696 - val_precision: 0.8696 - val_recall: 0.8696 - val_auc: 0.9641 - val_f1_Score: 0.8208 - lr: 1.0000e-04 - 2s/epoch - 376ms/step
# Epoch 15/30
# 5/5 - 2s - loss: 0.0491 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - auc: 0.9982 - f1_Score: 0.9824 - val_loss: 0.2951 - val_accuracy: 0.9130 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9433 - val_f1_Score: 0.8722 - lr: 1.0000e-04 - 2s/epoch - 380ms/step
# Epoch 16/30
# 5/5 - 2s - loss: 0.0167 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_Score: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9471 - val_f1_Score: 0.9309 - lr: 1.0000e-04 - 2s/epoch - 384ms/step
# Epoch 17/30
# 5/5 - 2s - loss: 0.1207 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9936 - f1_Score: 0.9642 - val_loss: 0.2788 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9452 - val_f1_Score: 0.9309 - lr: 1.0000e-04 - 2s/epoch - 385ms/step
# Epoch 18/30
# 5/5 - 2s - loss: 0.1372 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9923 - f1_Score: 0.9283 - val_loss: 0.2915 - val_accuracy: 0.8696 - val_precision: 0.8696 - val_recall: 0.8696 - val_auc: 0.9679 - val_f1_Score: 0.8208 - lr: 1.0000e-04 - 2s/epoch - 378ms/step
# Epoch 19/30
# 5/5 - 2s - loss: 0.0713 - accuracy: 0.9625 - precision: 0.9625 - recall: 0.9625 - auc: 0.9983 - f1_Score: 0.9491 - val_loss: 0.3076 - val_accuracy: 0.8696 - val_precision: 0.8696 - val_recall: 0.8696 - val_auc: 0.9565 - val_f1_Score: 0.8208 - lr: 1.0000e-04 - 2s/epoch - 389ms/step
# Epoch 20/30
# 5/5 - 2s - loss: 0.0670 - accuracy: 0.9625 - precision: 0.9625 - recall: 0.9625 - auc: 0.9973 - f1_Score: 0.9451 - val_loss: 0.4525 - val_accuracy: 0.7391 - val_precision: 0.7391 - val_recall: 0.7391 - val_auc: 0.8847 - val_f1_Score: 0.7125 - lr: 1.0000e-04 - 2s/epoch - 383ms/step
# Epoch 21/30
# 5/5 - 2s - loss: 0.0546 - accuracy: 0.9625 - precision: 0.9625 - recall: 0.9625 - auc: 0.9983 - f1_Score: 0.9473 - val_loss: 0.8812 - val_accuracy: 0.5217 - val_precision: 0.5217 - val_recall: 0.5217 - val_auc: 0.6673 - val_f1_Score: 0.5181 - lr: 1.0000e-04 - 2s/epoch - 381ms/step
# Epoch 22/30
# 5/5 - 2s - loss: 0.1841 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9822 - f1_Score: 0.8770 - val_loss: 0.3709 - val_accuracy: 0.7391 - val_precision: 0.7391 - val_recall: 0.7391 - val_auc: 0.9036 - val_f1_Score: 0.7125 - lr: 3.1623e-05 - 2s/epoch - 382ms/step
# Epoch 23/30
# 5/5 - 2s - loss: 0.0278 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - auc: 0.9998 - f1_Score: 0.9824 - val_loss: 0.1097 - val_accuracy: 0.9130 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9887 - val_f1_Score: 0.8722 - lr: 3.1623e-05 - 2s/epoch - 382ms/step
# Epoch 24/30
# 5/5 - 2s - loss: 0.0700 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9975 - f1_Score: 0.9333 - val_loss: 0.2435 - val_accuracy: 0.9130 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9811 - val_f1_Score: 0.8722 - lr: 3.1623e-05 - 2s/epoch - 405ms/step
# Epoch 25/30
# 5/5 - 2s - loss: 0.0876 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9955 - f1_Score: 0.9310 - val_loss: 0.3338 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9452 - val_f1_Score: 0.9309 - lr: 3.1623e-05 - 2s/epoch - 385ms/step
# Epoch 26/30
# 5/5 - 2s - loss: 0.0119 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_Score: 1.0000 - val_loss: 0.3814 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9433 - val_f1_Score: 0.9309 - lr: 3.1623e-05 - 2s/epoch - 389ms/step
# Epoch 27/30
# 5/5 - 2s - loss: 0.0068 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_Score: 1.0000 - val_loss: 0.4070 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9433 - val_f1_Score: 0.9309 - lr: 3.1623e-05 - 2s/epoch - 383ms/step
# Epoch 28/30
# 5/5 - 2s - loss: 0.0390 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - auc: 0.9992 - f1_Score: 0.9817 - val_loss: 0.4099 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9414 - val_f1_Score: 0.9309 - lr: 3.1623e-05 - 2s/epoch - 430ms/step
# Epoch 29/30
# 5/5 - 3s - loss: 0.0478 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9987 - f1_Score: 0.9655 - val_loss: 0.4377 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9433 - val_f1_Score: 0.9309 - lr: 1.0000e-05 - 3s/epoch - 584ms/step
# Epoch 30/30
# 5/5 - 2s - loss: 0.1498 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9870 - f1_Score: 0.9310 - val_loss: 0.4310 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9452 - val_f1_Score: 0.9309 - lr: 1.0000e-05 - 2s/epoch - 388ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
# ans = history.history['val_auc']
# ans

# %%
train_accuracy
# Out:
# [0.675000011920929,
#  0.8500000238418579,
#  0.7749999761581421,
#  0.925000011920929,
#  0.925000011920929,
#  0.8500000238418579,
#  0.925000011920929,
#  0.8999999761581421,
#  0.887499988079071,
#  0.9750000238418579,
#  0.9624999761581421,
#  0.987500011920929,
#  1.0,
#  1.0,
#  0.987500011920929,
#  1.0,
#  0.9750000238418579,
#  0.949999988079071,
#  0.9624999761581421,
#  0.9624999761581421,
#  0.9624999761581421,
#  0.9125000238418579,
#  0.987500011920929,
#  0.949999988079071,
#  0.949999988079071,
#  1.0,
#  1.0,
#  0.987500011920929,
#  0.9750000238418579,
#  0.949999988079071]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FYP/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 13 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 1/1 [==============================] - 8s 8s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 5/5 [==============================] - 2s 433ms/step - loss: 0.0015 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_Score: 1.0000

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.001518503064289689
# Train Accuracy: 1.0
# Train Precision: 1.0
# Train Recall: 1.0
# Train AUC: 1.0
# Train F1_Score: 1.0

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0142 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_Score: 1.0000

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.014178143814206123
# Test Accuracy: 1.0
# Test Precision: 1.0
# Test Recall: 1.0
# Test AUC: 1.0
# Test F1_Score: 1.0

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#      Nonnude       1.00      1.00      1.00         3
#         Nude       1.00      1.00      1.00        10
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']

# %%
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('csv_to_submit.csv', index = False)
